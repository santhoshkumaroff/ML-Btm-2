# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('Ice_cream selling data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Temperature (°C)         49 non-null     float64
#  1   Ice Cream Sales (units)  49 non-null     float64
# dtypes: float64(2)
# memory usage: 916.0 bytes

# %%
plt.scatter(df['Temperature (°C)'],df['Ice Cream Sales (units)'])

# %%
df.corr()
# Out:
#                          Temperature (°C)  Ice Cream Sales (units)
# Temperature (°C)                 1.000000                -0.175184
# Ice Cream Sales (units)         -0.175184                 1.000000

# %%
X = df[['Temperature (°C)']]
y = df['Ice Cream Sales (units)']

# %%
xtrain,xtest,ytrain,ytest = train_test_split(X,y,train_size=0.8,random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
model.score(xtrain,ytrain)
# Out:
# 0.06579063815950037

# %%
model.score(xtest,ytest)
# Out:
# -0.5751270190188227

# %%
poly = PolynomialFeatures(degree=2)

# %%
xtrain_poly = poly.fit_transform(xtrain)
xtest_poly = poly.transform(xtest)

# %%
xtrain
# Out:
#     Temperature (°C)
# 12         -2.111870
# 4          -3.578554
# 34          2.318591
# 8          -2.672461
# 3          -3.949661
# 6          -3.108440
# 40          3.211366
# 41          3.270044
# 46          4.130868
# 15         -1.326379
# 9          -2.652287
# 16         -1.173123
# 24          0.688781
# 33          2.075101
# 30          1.740000
# 0          -4.662263
# 43          3.335932
# 32          1.999310
# 5          -3.455712
# 29          1.359813
# 11         -2.288264
# 36          2.784836
# 1          -4.316559
# 21         -0.033895
# 2          -4.213985
# 37          2.831760
# 35          2.471946
# 23          0.149245
# 39          3.020874
# 10         -2.651498
# 22          0.008608
# 18         -0.673753
# 48          4.899032
# 20         -0.036156
# 7          -3.081303
# 42          3.316073
# 14         -1.660348
# 28          1.240712
# 38          2.959932

# %%
xtrain_poly
# Out:
# array([[ 1.00000000e+00, -2.11186969e+00,  4.45999359e+00],
#        [ 1.00000000e+00, -3.57855372e+00,  1.28060467e+01],
#        [ 1.00000000e+00,  2.31859124e+00,  5.37586534e+00],
#        [ 1.00000000e+00, -2.67246083e+00,  7.14204687e+00],
#        [ 1.00000000e+00, -3.94966109e+00,  1.55998227e+01],
#        [ 1.00000000e+00, -3.10844012e+00,  9.66239999e+00],
#        [ 1.00000000e+00,  3.21136614e+00,  1.03128725e+01],
#        [ 1.00000000e+00,  3.27004407e+00,  1.06931882e+01],
#        [ 1.00000000e+00,  4.13086796e+00,  1.70640701e+01],
#        [ 1.00000000e+00, -1.32637898e+00,  1.75928121e+00],
#        [ 1.00000000e+00, -2.65228679e+00,  7.03462523e+00],
#        [ 1.00000000e+00, -1.17312327e+00,  1.37621820e+00],
#        [ 1.00000000e+00,  6.88780908e-01,  4.74419139e-01],
#        [ 1.00000000e+00,  2.07510060e+00,  4.30604249e+00],
#        [ 1.00000000e+00,  1.74000001e+00,  3.02760004e+00],
#        [ 1.00000000e+00, -4.66226268e+00,  2.17366933e+01],
# ...

# %%
model = LinearRegression()

# %%
model.fit(xtrain_poly,ytrain)
# Out:
# LinearRegression()

# %%
model.score(xtrain_poly,ytrain)
# Out:
# 0.9413665676490518

# %%
xtrain
# Out:
#     Temperature (°C)
# 12         -2.111870
# 4          -3.578554
# 34          2.318591
# 8          -2.672461
# 3          -3.949661
# 6          -3.108440
# 40          3.211366
# 41          3.270044
# 46          4.130868
# 15         -1.326379
# 9          -2.652287
# 16         -1.173123
# 24          0.688781
# 33          2.075101
# 30          1.740000
# 0          -4.662263
# 43          3.335932
# 32          1.999310
# 5          -3.455712
# 29          1.359813
# 11         -2.288264
# 36          2.784836
# 1          -4.316559
# 21         -0.033895
# 2          -4.213985
# 37          2.831760
# 35          2.471946
# 23          0.149245
# 39          3.020874
# 10         -2.651498
# 22          0.008608
# 18         -0.673753
# 48          4.899032
# 20         -0.036156
# 7          -3.081303
# 42          3.316073
# 14         -1.660348
# 28          1.240712
# 38          2.959932

# %%
plt.scatter(xtrain['Temperature (°C)'],ytrain)
plt.scatter(xtrain['Temperature (°C)'],model.predict(xtrain_poly))
''' 
model.fit(xtrain_poly,ytrain)xtrain_poly has 3 columns
model.predict(xtrain) xtrain has only 1 column
when the features number differs we will get this error
ValueError: X has 1 features, but LinearRegression is expecting 3 features as input.
'''
# Out:
# ' \nmodel.fit(xtrain_poly,ytrain)xtrain_poly has 3 columns\nmodel.predict(xtrain) xtrain has only 1 column\nif the features number differs we will get this error\nValueError: X has 1 features, but LinearRegression is expecting 3 features as input.\n\n'

# %%
df['new'] = df['Temperature (°C)']

# %%
df
# Out:
#     Temperature (°C)  Ice Cream Sales (units)       new
# 0          -4.662263                41.842986 -4.662263
# 1          -4.316559                34.661120 -4.316559
# 2          -4.213985                39.383001 -4.213985
# 3          -3.949661                37.539845 -3.949661
# 4          -3.578554                32.284531 -3.578554
# 5          -3.455712                30.001138 -3.455712
# 6          -3.108440                22.635401 -3.108440
# 7          -3.081303                25.365022 -3.081303
# 8          -2.672461                19.226970 -2.672461
# 9          -2.652287                20.279679 -2.652287
# 10         -2.651498                13.275828 -2.651498
# 11         -2.288264                18.123991 -2.288264
# 12         -2.111870                11.218294 -2.111870
# 13         -1.818938                10.012868 -1.818938
# 14         -1.660348                12.615181 -1.660348
# 15         -1.326379                10.957731 -1.326379
# ...

# %%
model = LinearRegression()
model.fit(df[['Temperature (°C)']],df['Ice Cream Sales (units)'])
# Out:
# LinearRegression()

# %%
'''
model = LinearRegression()
model.fit(df[['Temperature (°C)']],df['Ice Cream Sales (units)'])
model.predict(df[['new']])
ValueError                                
...
Feature names unseen at fit time:
- new
Feature names seen at fit time, yet now missing:
- Temperature (°C)
'''
# Out:
# "\nmodel = LinearRegression()\nmodel.fit(df[['Temperature (°C)']],df['Ice Cream Sales (units)'])\nmodel.predict(df[['new']])\nValueError                                \n...\nFeature names unseen at fit time:\n- new\nFeature names seen at fit time, yet now missing:\n- Temperature (°C)\n"
